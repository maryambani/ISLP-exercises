# %% [markdown]
# (a) Use the pd.read_csv() function to read the data into Python. Call
# the loaded data college. Make sure that you have the directory
# set to the correct location for the data.

# %%
import pandas as pd

college = pd.read_csv("./csv/College.csv")
college
# Out:
#                          Unnamed: 0 Private   Apps  Accept  Enroll  Top10perc  \
# 0      Abilene Christian University     Yes   1660    1232     721         23
# 1                Adelphi University     Yes   2186    1924     512         16
# 2                    Adrian College     Yes   1428    1097     336         22
# 3               Agnes Scott College     Yes    417     349     137         60
# 4         Alaska Pacific University     Yes    193     146      55         16
# ..                              ...     ...    ...     ...     ...        ...
# 772         Worcester State College      No   2197    1515     543          4
# 773               Xavier University     Yes   1959    1805     695         24
# 774  Xavier University of Louisiana     Yes   2097    1915     695         34
# 775                 Yale University     Yes  10705    2453    1317         95
# 776    York College of Pennsylvania     Yes   2989    1855     691         28
#
# ...

# %%
"College columns:", college.columns
# Out:
# ('College columns:',
#  Index(['Unnamed: 0', 'Private', 'Apps', 'Accept', 'Enroll', 'Top10perc',
#         'Top25perc', 'F.Undergrad', 'P.Undergrad', 'Outstate', 'Room.Board',
#         'Books', 'Personal', 'PhD', 'Terminal', 'S.F.Ratio', 'perc.alumni',
#         'Expend', 'Grad.Rate'],
#        dtype='object'))

# %% [markdown]
# (b) Look at the data used in the notebook by creating and running
# a new cell with just the code college in it. You should notice
# that the first column is just the name of each university in a
# column named something like Unnamed: 0. We don’t really want
# pandas to treat this as data. However, it may be handy to have
# these names for later. Try the following commands and similarly
# look at the resulting data frames:

# %%
college2 = pd.read_csv('./csv/College.csv', index_col=0)
college3 = college.rename({'Unnamed: 0':'College'}, axis =1)
college3 = college3.set_index('College')

college3
college2
# Out:
#                                Private   Apps  Accept  Enroll  Top10perc  \
# Abilene Christian University       Yes   1660    1232     721         23
# Adelphi University                 Yes   2186    1924     512         16
# Adrian College                     Yes   1428    1097     336         22
# Agnes Scott College                Yes    417     349     137         60
# Alaska Pacific University          Yes    193     146      55         16
# ...                                ...    ...     ...     ...        ...
# Worcester State College             No   2197    1515     543          4
# Xavier University                  Yes   1959    1805     695         24
# Xavier University of Louisiana     Yes   2097    1915     695         34
# Yale University                    Yes  10705    2453    1317         95
# York College of Pennsylvania       Yes   2989    1855     691         28
#
#                                 Top25perc  F.Undergrad  P.Undergrad  Outstate  \
# ...

# %%
"\nCollege2 columns:", college2.columns
# Out:
# ('\nCollege2 columns:',
#  Index(['Private', 'Apps', 'Accept', 'Enroll', 'Top10perc', 'Top25perc',
#         'F.Undergrad', 'P.Undergrad', 'Outstate', 'Room.Board', 'Books',
#         'Personal', 'PhD', 'Terminal', 'S.F.Ratio', 'perc.alumni', 'Expend',
#         'Grad.Rate'],
#        dtype='object'))

# %%
college = college3

# %% [markdown]
# (c) Use the describe() method of to produce a numerical summary
# of the variables in the data set.

# %%
college.describe()
# Out:
#                Apps        Accept       Enroll   Top10perc   Top25perc  \
# count    777.000000    777.000000   777.000000  777.000000  777.000000
# mean    3001.638353   2018.804376   779.972973   27.558559   55.796654
# std     3870.201484   2451.113971   929.176190   17.640364   19.804778
# min       81.000000     72.000000    35.000000    1.000000    9.000000
# 25%      776.000000    604.000000   242.000000   15.000000   41.000000
# 50%     1558.000000   1110.000000   434.000000   23.000000   54.000000
# 75%     3624.000000   2424.000000   902.000000   35.000000   69.000000
# max    48094.000000  26330.000000  6392.000000   96.000000  100.000000
#
#         F.Undergrad   P.Undergrad      Outstate   Room.Board        Books  \
# count    777.000000    777.000000    777.000000   777.000000   777.000000
# mean    3699.907336    855.298584  10440.669241  4357.526384   549.380952
# std     4850.420531   1522.431887   4023.016484  1096.696416   165.105360
# ...

# %% [markdown]
# (d) Use the pd.plotting.scatter_matrix() function to produce a
# scatterplot matrix of the first columns [Top10perc, Apps, Enroll].
# Recall that you can reference a list C of columns of a data frame
# A using A[C].

# %%
pd.plotting.scatter_matrix(college.iloc[:,[3,0,2]])
# iloc pattern: iloc[row_selection, column_selection] and if you use : it means select all rows or columns
# for first 5 rows it would be 0:5 for instance
# Out:
# array([[<Axes: xlabel='Enroll', ylabel='Enroll'>,
#         <Axes: xlabel='Accept', ylabel='Enroll'>],
#        [<Axes: xlabel='Enroll', ylabel='Accept'>,
#         <Axes: xlabel='Accept', ylabel='Accept'>]], dtype=object)

# %%
print("Column at position 3:", college.columns[3])  # Should be 'Enroll'
print("Column at position 0:", college.columns[0])  # Might be 'Unnamed: 0' or 'Private'
print("Column at position 2:", college.columns[2])
# Out:
# Column at position 3: Enroll
# Column at position 0: Private
# Column at position 2: Accept

# %%
for i, col in enumerate(college.columns):
    print(f"Position {i}: {col}")
# Out:
# Position 0: Private
# Position 1: Apps
# Position 2: Accept
# Position 3: Enroll
# Position 4: Top10perc
# Position 5: Top25perc
# Position 6: F.Undergrad
# Position 7: P.Undergrad
# Position 8: Outstate
# Position 9: Room.Board
# Position 10: Books
# Position 11: Personal
# Position 12: PhD
# Position 13: Terminal
# Position 14: S.F.Ratio
# Position 15: perc.alumni
# Position 16: Expend
# Position 17: Grad.Rate

# %%
pd.plotting.scatter_matrix(college.iloc[:,[3,4,2]])
# iloc pattern: iloc[row_selection, column_selection] and if you use : it means select all rows or columns
# for first 5 rows it would be 0:5 for instance
# Out:
# array([[<Axes: xlabel='Enroll', ylabel='Enroll'>,
#         <Axes: xlabel='Top10perc', ylabel='Enroll'>,
#         <Axes: xlabel='Accept', ylabel='Enroll'>],
#        [<Axes: xlabel='Enroll', ylabel='Top10perc'>,
#         <Axes: xlabel='Top10perc', ylabel='Top10perc'>,
#         <Axes: xlabel='Accept', ylabel='Top10perc'>],
#        [<Axes: xlabel='Enroll', ylabel='Accept'>,
#         <Axes: xlabel='Top10perc', ylabel='Accept'>,
#         <Axes: xlabel='Accept', ylabel='Accept'>]], dtype=object)

# %%
# alternative:
columns_to_plot = ['Top10perc', 'Apps', 'Enroll']
pd.plotting.scatter_matrix(college[columns_to_plot])
# Out:
# array([[<Axes: xlabel='Top10perc', ylabel='Top10perc'>,
#         <Axes: xlabel='Apps', ylabel='Top10perc'>,
#         <Axes: xlabel='Enroll', ylabel='Top10perc'>],
#        [<Axes: xlabel='Top10perc', ylabel='Apps'>,
#         <Axes: xlabel='Apps', ylabel='Apps'>,
#         <Axes: xlabel='Enroll', ylabel='Apps'>],
#        [<Axes: xlabel='Top10perc', ylabel='Enroll'>,
#         <Axes: xlabel='Apps', ylabel='Enroll'>,
#         <Axes: xlabel='Enroll', ylabel='Enroll'>]], dtype=object)

# %% [markdown]
# Use the boxplot() method of college to produce side-by-side
# boxplots of Outstate versus Private.

# %%
college.boxplot(column='Outstate', by='Private')
# in a box plot you have
# outlier points
# whiskers that extend to most extremember non outlier
#top of the box (75th percentile or upper quartile Q3), middle of the box: median line or 50th percentile
#bottom of the box: lower quartile or 25th percentile Q1
# whisker at the bottom extends to most extreme non outlier
# and then might have any outlier point at the bottom

# a boxplot will compare the out of state tuition cost between the ones that are private vs the ones that are not private
# so the left box (not private or public) will show how much the tuition out of state typically is
# Out:
# <Axes: title={'center': 'Outstate'}, xlabel='Private'>

# %% [markdown]
# (f) Create a new qualitative variable, called Elite, by binning the
# Top10perc variable into two groups based on whether or not the
# proportion of students coming from the top 10% of their high
# school classes exceeds 50%.

# %%
college['Elite'] = pd.cut(college['Top10perc'], [0, 50, 100], labels =['No','Yes'])

# %% [markdown]
# Use the value_counts() method of college['Elite'] to see how
# many elite universities there are. Finally, use the boxplot() method
# again to produce side-by-side boxplots of Outstate versus Elite.

# %%
elite_counts = college['Elite'].value_counts()
elite_counts
# Out:
# Elite
# No     699
# Yes     78
# Name: count, dtype: int64

# %%
college.boxplot(column='Outstate', by='Elite')
# Out:
# <Axes: title={'center': 'Outstate'}, xlabel='Elite'>

# %% [markdown]
# (g) Use the plot.hist() method of college to produce some his-
# tograms with differing numbers of bins for a few of the quanti-
# tative variables. The command plt.subplots(2, 2) may be use-
# ful: it will divide the plot window into four regions so that four
# plots can be made simultaneously. By changing the arguments
# you can divide the screen up in other combinations.

# %%
import matplotlib.pyplot as plt

# %%
plt.subplots?
# Out:
# Signature:
# plt.subplots(
#     nrows: 'int' = 1,
#     ncols: 'int' = 1,
#     *,
#     sharex: "bool | Literal['none', 'all', 'row', 'col']" = False,
#     sharey: "bool | Literal['none', 'all', 'row', 'col']" = False,
#     squeeze: 'bool' = True,
#     width_ratios: 'Sequence[float] | None' = None,
#     height_ratios: 'Sequence[float] | None' = None,
#     subplot_kw: 'dict[str, Any] | None' = None,
#     gridspec_kw: 'dict[str, Any] | None' = None,
#     **fig_kw,
# ) -> 'tuple[Figure, Any]'
# Docstring:
# Create a figure and a set of subplots.
#
# This utility wrapper makes it convenient to create common layouts of
# subplots, including the enclosing figure object, in a single call.
#
# Parameters
# ----------
# nrows, ncols : int, default: 1
#     Number of rows/columns of the subplot grid.
#
# sharex, sharey : bool or {'none', 'all', 'row', 'col'}, default: False
#     Controls sharing of properties among x (*sharex*) or y (*sharey*)
#     axes:
#
# ...

# %%
fig, axes = plt.subplots(2, 2)

# %%
axes
# Out:
# array([[<Axes: >, <Axes: >],
#        [<Axes: >, <Axes: >]], dtype=object)

# %%
# Quantitative variables: Apps, Accept, Top10perc, Top25perc, Books
axes[0,0].set_title('Applications')
axes[0,0].hist(college.Apps, color='skyblue')
axes[0,0].set_ylabel('Number of Colleges')
axes[0,0].set_xlabel('Applications received')
axes[0,1].set_title('Acceptances')
axes[0,1].hist(college.Accept, color='salmon')
axes[0,1].set_xlabel('Number of students accepted')

axes[1,0].set_title('Students from top 10 percent of high school class')
axes[1,0].hist(college.Top10perc, color='lightgreen')
axes[1,0].set_xlabel('Number of students')
axes[1,0].set_ylabel('Number of Colleges')
# plt.hist(college.Top25perc)
axes[1,1].set_title('Estimated book costs')
axes[1,1].set_xlabel('Costs')
axes[1,1].hist(college.Books, color='plum')
axes[0,1].set_ylabel('Number of Colleges')
axes[1,1].set_ylabel('Number of Colleges')
fig.tight_layout() # to prevent overlap
fig

# %% [markdown]
# This exercise involves the Auto data set studied in the lab. Make sure
# that the missing values have been removed from the data.
# (a) Which of the predictors are quantitative, and which are quali-
# tative?
#
# We have the following predictors:
# mpg	cylinders	displacement	horsepower	weight	acceleration	year	origin	name
# Where qualitative are the cylinders, origin and name
# Quantitative are the mpg, displacement, horsepower, weight, acceleration and year

# %% [markdown]
# (b) What is the range of each quantitative predictor? You can an-
# swer this using the min() and max() methods in numpy

# %%
Auto = pd.read_csv('./csv/Auto.csv')
Auto

# Auto[Auto['horsepower'] == '?']
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  year  \
# 0    18.0          8         307.0         130    3504          12.0    70
# 1    15.0          8         350.0         165    3693          11.5    70
# 2    18.0          8         318.0         150    3436          11.0    70
# 3    16.0          8         304.0         150    3433          12.0    70
# 4    17.0          8         302.0         140    3449          10.5    70
# ..    ...        ...           ...         ...     ...           ...   ...
# 387  27.0          4         140.0          86    2790          15.6    82
# 388  44.0          4          97.0          52    2130          24.6    82
# 389  32.0          4         135.0          84    2295          11.6    82
# 390  28.0          4         120.0          79    2625          18.6    82
# 391  31.0          4         119.0          82    2720          19.4    82
#
#      origin                       name
# ...

# %%
ranges = pd.DataFrame({
    'Min': Auto[['mpg', 'displacement', 'horsepower', 'weight', 'acceleration', 'year']].min(),
    'Max': Auto[['mpg', 'displacement', 'horsepower', 'weight', 'acceleration', 'year']].max()
})
ranges
# Out:
#                  Min     Max
# mpg              9.0    46.6
# displacement    68.0   455.0
# horsepower      46.0   230.0
# weight        1613.0  5140.0
# acceleration     8.0    24.8
# year            70.0    82.0

# %% [markdown]
# (c) What is the mean and standard deviation of each quantitative
# predictor?

# %%
summary_stats = pd.DataFrame({
    'Mean': Auto[['mpg', 'displacement', 'horsepower', 'weight', 'acceleration', 'year']].mean(),
    'Standard deviation': Auto[['mpg', 'displacement', 'horsepower', 'weight', 'acceleration', 'year']].std()
})
summary_stats
# Out:
#                      Mean  Standard deviation
# mpg             23.445918            7.805007
# displacement   194.411990          104.644004
# horsepower     104.469388           38.491160
# weight        2977.584184          849.402560
# acceleration    15.541327            2.758864
# year            75.979592            3.683737

# %%
summary_stats.index
# Out:
# Index(['mpg', 'displacement', 'horsepower', 'weight', 'acceleration', 'year'], dtype='object')

# %%
summary_stats['Mean']
# Out:
# mpg               23.445918
# displacement     194.411990
# horsepower       104.469388
# weight          2977.584184
# acceleration      15.541327
# year              75.979592
# Name: Mean, dtype: float64

# %%
plt.figure(figsize=(10,6))
plt.title('Mean and standard deviation')
plt.grid()
plt.errorbar(summary_stats.index, summary_stats['Mean'], summary_stats['Standard deviation'],fmt='bo', ecolor='orange')
# Out:
# <ErrorbarContainer object of 3 artists>

# %% [markdown]
# (d) Now remove the 10th through 85th observations. What is the
# range, mean, and standard deviation of each predictor in the
# subset of the data that remains?

# %%
Auto_exclude = pd.concat([Auto.iloc[:10], Auto.iloc[86:]])
# removing 10th to 85th observation
Auto_exclude
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  year  \
# 0    18.0          8         307.0         130    3504          12.0    70
# 1    15.0          8         350.0         165    3693          11.5    70
# 2    18.0          8         318.0         150    3436          11.0    70
# 3    16.0          8         304.0         150    3433          12.0    70
# 4    17.0          8         302.0         140    3449          10.5    70
# ..    ...        ...           ...         ...     ...           ...   ...
# 387  27.0          4         140.0          86    2790          15.6    82
# 388  44.0          4          97.0          52    2130          24.6    82
# 389  32.0          4         135.0          84    2295          11.6    82
# 390  28.0          4         120.0          79    2625          18.6    82
# 391  31.0          4         119.0          82    2720          19.4    82
#
#      origin                       name
# ...

# %%
ranges_excl = pd.DataFrame({
    'Min': Auto_exclude[['mpg', 'displacement', 'horsepower', 'weight', 'acceleration', 'year']].min(),
    'Max': Auto_exclude[['mpg', 'displacement', 'horsepower', 'weight', 'acceleration', 'year']].max()
})
ranges_excl
# Out:
#                  Min     Max
# mpg             11.0    46.6
# displacement    68.0   455.0
# horsepower      46.0   230.0
# weight        1649.0  4997.0
# acceleration     8.5    24.8
# year            70.0    82.0

# %%
summary_stats_excl = pd.DataFrame({
    'Mean': Auto_exclude[['mpg', 'displacement', 'horsepower', 'weight', 'acceleration', 'year']].mean(),
    'Standard deviation': Auto_exclude[['mpg', 'displacement', 'horsepower', 'weight', 'acceleration', 'year']].std()
})
summary_stats_excl
# Out:
#                      Mean  Standard deviation
# mpg             24.407595            7.863285
# displacement   187.512658          100.114616
# horsepower     100.848101           35.954147
# weight        2936.534810          811.874450
# acceleration    15.717405            2.713876
# year            77.136076            3.123464

# %%
plt.figure(figsize=(10,6))
plt.title('Mean and standard deviation')
plt.grid()
plt.errorbar(summary_stats_excl.index, summary_stats_excl['Mean'], summary_stats_excl['Standard deviation'],fmt='r^', ecolor='orange')
# Out:
# <ErrorbarContainer object of 3 artists>

# %%
scatter = pd.plotting.scatter_matrix(Auto[['mpg', 'displacement', 'horsepower', 'weight', 'acceleration', 'year']], figsize=(12,12), alpha=0.5)

# %% [markdown]
# Negative correlation between mpg and displacement, mpg and horsepower, mpg and weight.
# Positive correlation displacement and horsepower, displacement and weight
#
# MPG has an upward trend when looking at the year so cars got better gas mileage over time
#
# Overall a downward trend with horsepower and year as technology improves
#
# Lines because years are discrete; cars from same year line up vertically on graph

# %% [markdown]
# (f) Suppose that we wish to predict gas mileage (mpg) on the basis
# of the other variables. Do your plots suggest that any of the
# other variables might be useful in predicting mpg? Justify your
# answer.
#
# Yes, many variables may be useful in predicting mpg. With the scatterplot it has been noticed that there is a negative correlation between weight vs mpg, horsepower vs mpg, displacement vs mpg. There is a weak relationship between mpg and acceleration but it may still be valuable in prediction. There is also a positive correlation with the year.

# %% [markdown]
# This exercise involves the Boston housing data set.
# (a) To begin, load in the Boston data set, which is part of the ISLP
# library.

# %%
Boston = pd.read_csv('./csv/Boston.csv')
Boston
# Out:
#      Unnamed: 0     crim    zn  indus  chas    nox     rm   age     dis  rad  \
# 0             1  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1
# 1             2  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2
# 2             3  0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2
# 3             4  0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3
# 4             5  0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3
# ..          ...      ...   ...    ...   ...    ...    ...   ...     ...  ...
# 501         502  0.06263   0.0  11.93     0  0.573  6.593  69.1  2.4786    1
# 502         503  0.04527   0.0  11.93     0  0.573  6.120  76.7  2.2875    1
# 503         504  0.06076   0.0  11.93     0  0.573  6.976  91.0  2.1675    1
# 504         505  0.10959   0.0  11.93     0  0.573  6.794  89.3  2.3889    1
# 505         506  0.04741   0.0  11.93     0  0.573  6.030  80.8  2.5050    1
#
#      tax  ptratio  lstat  medv
# ...

# %% [markdown]
# (b) How many rows are in this data set? How many columns? What
# do the rows and columns represent?
#
# 506 rows × 14 columns
# Unnamed: 0	crim	zn	indus	chas	nox	rm	age	dis	rad	tax	ptratio	lstat	medv
#
# crime rate
# industrial land?
# rooms
# age

# %% [markdown]
# (c) Make some pairwise scatterplots of the predictors (columns) in
# this data set. Describe your findings.

# %%
scatterplots = pd.plotting.scatter_matrix(Boston[['crim', 'zn', 'indus', 'chas', 'nox', 'rm', 'age', 'dis', 'rad', 'tax', 'ptratio', 'lstat', 'medv']], figsize=(12,12), alpha=0.5)

# %% [markdown]
# Positive correlations:
# Age & nox
# Older homes have higher pollution levels
# Medv and rm (home value and rooms)
# Larger homes are worth more
# dis and medv
# lstat and indus
#
# Negative correlation
# Dis and nox
# lstat and rm
# medv and lstat
# medv and lstat

# %% [markdown]
# (d) Are any of the predictors associated with per capita crime rate?
# If so, explain the relationship.
#
# nox has a positive correlation with crime rate, meaning that areas with higher crime rates are accompanied by higher pollution rate (nitrogen oxide in the air) which can make sense for urban/industrial areas
# There is also a less noticeable relationship with rm with a negative correlation where higher crime rates are associated with smaller room sizes, suggesting socioeconomic connections (smaller homes)
# Age (positive) and distance (negative) suggesting suburban vs urban pattern
#
# Some have a skew like ptratio, indus, tax and rad

# %%
import sys
sys.executable
# Out:
# '/Users/maryam/anaconda3/bin/python'

# %%
# !conda install -n islp seaborn -y
# Out:
# ...
# Solving environment: done
#
#
# ==> WARNING: A newer version of conda exists. <==
#   current version: 23.7.4
#   latest version: 24.11.1
#
# Please update conda by running
#
#     $ conda update -n base -c defaults conda
#
# Or to minimize the number of packages updated during conda update use
#
#      conda install conda=24.11.1
#
#
#
# # All requested packages already installed.

# %%
import seaborn as sns

# %%
fig, (ax1, ax2, ax3) = plt.subplots(1, 3, figsize=(15, 5))

# Crime Rate Distribution
sns.boxplot(y=Boston['crim'], ax=ax1, boxprops={'facecolor': 'white'})
sns.stripplot(y=Boston['crim'], color='black', alpha=0.3, ax=ax1)
ax1.set_title('Crime Rate Distribution')
ax1.set_ylabel('Crime Rate')

# Tax Rate Distribution
sns.boxplot(y=Boston['tax'], ax=ax2, boxprops={'facecolor': 'white'})
sns.stripplot(y=Boston['tax'], color='black', alpha=0.3, ax=ax2)
ax2.set_title('Tax Rate Distribution')
ax2.set_ylabel('Tax Rate')

# Pupil-Teacher Ratio Distribution
sns.boxplot(y=Boston['ptratio'], ax=ax3, boxprops={'facecolor': 'white'})
sns.stripplot(y=Boston['ptratio'], color='black', alpha=0.3, ax=ax3)
ax3.set_title('Pupil-Teacher Ratio Distribution')
ax3.set_ylabel('Pupil-Teacher Ratio')

plt.tight_layout()

# %% [markdown]
# Most areas in boston have low crime rates but there are some exterme outliers with some rates around 80-90. Most are less than 10
# Range is between 200 and 700 roughly with most of them clustering between 280 and 400. Theres a group of higher tax suburbs aroudn 650-700
# Pupil teacher ratio shows the range is around 13 and 22. Most are around 17 to 20 students per teacher . Overall its more evenly distributed. Some suburbs have higher ratios around 21 students and some have smaller ratios at around 15 students

# %% [markdown]
# (f) How many of the suburbs in this data set bound the Charles
# river?

# %%
charles_river_count = Boston['chas'].sum()
charles_river_count
# Out:
# 35

# %% [markdown]
# There are 35 suburbs that bound the Charles river.

# %% [markdown]
# (g) What is the median pupil-teacher ratio among the towns in this
# data set?

# %%
Boston['ptratio'].median()
# Out:
# 19.05

# %%
Boston['ptratio'].describe()
# Out:
# count    506.000000
# mean      18.455534
# std        2.164946
# min       12.600000
# 25%       17.400000
# 50%       19.050000
# 75%       20.200000
# max       22.000000
# Name: ptratio, dtype: float64

# %% [markdown]
# (h) Which suburb of Boston has lowest median value of owner-
# occupied homes? What are the values of the other predictors
# for that suburb, and how do those values compare to the overall
# ranges for those predictors? Comment on your findings.

# %%
Boston['medv'].describe()
# Out:
# count    506.000000
# mean      22.532806
# std        9.197104
# min        5.000000
# 25%       17.025000
# 50%       21.200000
# 75%       25.000000
# max       50.000000
# Name: medv, dtype: float64

# %% [markdown]
# The lowest median value is 5.00

# %%
Boston['medv'].idxmin()
# Out:
# 398

# %%
Boston.loc[Boston['medv'].idxmin()]
# Out:
# Unnamed: 0    399.0000
# crim           38.3518
# zn              0.0000
# indus          18.1000
# chas            0.0000
# nox             0.6930
# rm              5.4530
# age           100.0000
# dis             1.4896
# rad            24.0000
# tax           666.0000
# ptratio        20.2000
# lstat          30.5900
# medv            5.0000
# Name: 398, dtype: float64

# %%
Boston[Boston['medv'] == Boston['medv'].min()]
# Out:
#      Unnamed: 0     crim   zn  indus  chas    nox     rm    age     dis  rad  \
# 398         399  38.3518  0.0   18.1     0  0.693  5.453  100.0  1.4896   24
# 405         406  67.9208  0.0   18.1     0  0.693  5.683  100.0  1.4254   24
#
#      tax  ptratio  lstat  medv
# 398  666     20.2  30.59   5.0
# 405  666     20.2  22.98   5.0

# %% [markdown]
# The 399th and 406th have the lowest median at 5 of owner occupied homes.

# %%
Boston.describe()
# Out:
#        Unnamed: 0        crim          zn       indus        chas         nox  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean   253.500000    3.613524   11.363636   11.136779    0.069170    0.554695
# std    146.213884    8.601545   23.322453    6.860353    0.253994    0.115878
# min      1.000000    0.006320    0.000000    0.460000    0.000000    0.385000
# 25%    127.250000    0.082045    0.000000    5.190000    0.000000    0.449000
# 50%    253.500000    0.256510    0.000000    9.690000    0.000000    0.538000
# 75%    379.750000    3.677083   12.500000   18.100000    0.000000    0.624000
# max    506.000000   88.976200  100.000000   27.740000    1.000000    0.871000
#
#                rm         age         dis         rad         tax     ptratio  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean     6.284634   68.574901    3.795043    9.549407  408.237154   18.455534
# ...

# %% [markdown]
# The crime rates are higher than the mean and median of all suburbs. It is also closer to industrial places. There are also higher pollution rates when comparing to the mean and median. The rm is close to the mean but less than the mean (5-6 homes per average but less than the average of 6.28 rooms per avg). The age is 100 higher than all other suburbs. the distance is less than other suburbs. The rad is the maximal value (better access to radial highways). The tax bracket is on the higher side. the ptratio is also on the higher side at 20. The lstat is also higher.

# %% [markdown]
# (i) In this data set, how many of the suburbs average more than
# seven rooms per dwelling? More than eight rooms per dwelling?
# Comment on the suburbs that average more than eight rooms
# per dwelling.

# %%
Boston[Boston['rm'] > 7]
# Out:
#      Unnamed: 0      crim    zn  indus  chas     nox     rm   age     dis  \
# 2             3   0.02729   0.0   7.07     0  0.4690  7.185  61.1  4.9671
# 4             5   0.06905   0.0   2.18     0  0.4580  7.147  54.2  6.0622
# 40           41   0.03359  75.0   2.95     0  0.4280  7.024  15.8  5.4011
# 55           56   0.01311  90.0   1.22     0  0.4030  7.249  21.9  8.6966
# 64           65   0.01951  17.5   1.38     0  0.4161  7.104  59.5  9.2229
# ..          ...       ...   ...    ...   ...     ...    ...   ...     ...
# 364         365   3.47428   0.0  18.10     1  0.7180  8.780  82.9  1.9047
# 370         371   6.53876   0.0  18.10     1  0.6310  7.016  97.5  1.2024
# 375         376  19.60910   0.0  18.10     0  0.6710  7.313  97.9  1.3163
# 453         454   8.24809   0.0  18.10     0  0.7130  7.393  99.3  2.4527
# 482         483   5.73116   0.0  18.10     0  0.5320  7.061  77.0  3.4106
#
#      rad  tax  ptratio  lstat  medv
# 2      2  242     17.8   4.03  34.7
# ...

# %% [markdown]
# 64 that have more than 7 rooms per dwelling

# %%
len(Boston[Boston['rm'] > 8])
# Out:
# 13

# %%
Boston[Boston['rm'] > 8]
# Out:
#      Unnamed: 0     crim    zn  indus  chas     nox     rm   age     dis  rad  \
# 97           98  0.12083   0.0   2.89     0  0.4450  8.069  76.0  3.4952    2
# 163         164  1.51902   0.0  19.58     1  0.6050  8.375  93.9  2.1620    5
# 204         205  0.02009  95.0   2.68     0  0.4161  8.034  31.9  5.1180    4
# 224         225  0.31533   0.0   6.20     0  0.5040  8.266  78.3  2.8944    8
# 225         226  0.52693   0.0   6.20     0  0.5040  8.725  83.0  2.8944    8
# 226         227  0.38214   0.0   6.20     0  0.5040  8.040  86.5  3.2157    8
# 232         233  0.57529   0.0   6.20     0  0.5070  8.337  73.3  3.8384    8
# 233         234  0.33147   0.0   6.20     0  0.5070  8.247  70.4  3.6519    8
# 253         254  0.36894  22.0   5.86     0  0.4310  8.259   8.4  8.9067    7
# 257         258  0.61154  20.0   3.97     0  0.6470  8.704  86.9  1.8010    5
# 262         263  0.52014  20.0   3.97     0  0.6470  8.398  91.5  2.2885    5
# ...

# %% [markdown]
# 13 that have more than 8 rooms per dwelling
